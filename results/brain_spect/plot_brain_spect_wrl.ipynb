# %%
import qmirt
from matplotlib import pyplot as plt
import numpy as np
from plotly import graph_objects as go

# %%
brain_spect_3d_fig = qmirt.plot.wrl.plot_wrl_file("brain_spect_geometry.wrl", style_sheet="geometry_style.json",title="Brain SPECT Geometry")
brain_spect_3d_fig.show()
